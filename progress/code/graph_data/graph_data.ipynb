# %%
import pandas as pd
import matplotlib.pyplot as plt

input_csv = pd.read_csv(
r"C:\Users\Kohsu\Desktop\graduation_thesis\progress\data\data.csv"
)

# x軸：四半期を文字列として扱う
x = input_csv.iloc[:, 0].astype(str)

# y軸：R
R = input_csv["R"]

plt.figure(figsize=(8, 4))

plt.plot(
x,
R,
linestyle="solid",
marker="o"
)

plt.ylabel("%")
plt.xticks(
    range(0, len(x), 2),
    x.iloc[::2],
    rotation=90
)
plt.title("R")

plt.grid(True)

plt.tight_layout()
plt.savefig("R_data.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# x軸：四半期を文字列として扱う
x = input_csv.iloc[:, 0].astype(str)

# y軸：b
b = input_csv["b"]/1000

plt.figure(figsize=(8, 4))

plt.plot(
x,
b,
linestyle="solid",
marker="o"
)

plt.ylabel("1 billion yen")
plt.xticks(
    range(0, len(x), 2),
    x.iloc[::2],
    rotation=90
)
plt.title("b")

plt.grid(True)

plt.tight_layout()
plt.savefig("b_data.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# x軸：四半期を文字列として扱う
x = input_csv.iloc[:, 0].astype(str)

# y軸：k
k = input_csv["k"]/1000

plt.figure(figsize=(8, 4))

plt.plot(
x,
k,
linestyle="solid",
marker="o"
)

plt.ylabel("1 billion yen")
plt.xticks(
    range(0, len(x), 2),
    x.iloc[::2],
    rotation=90
)
plt.title("k")

plt.grid(True)

plt.tight_layout()
plt.savefig("k_data.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# x軸：四半期を文字列として扱う
xx = input_csv.iloc[:, 0].astype(str)

# y軸：x
x = input_csv["x"]/1000

plt.figure(figsize=(8, 4))

plt.plot(
xx,
x,
linestyle="solid",
marker="o"
)

plt.ylabel("1 billion yen")
plt.xticks(
    range(0, len(xx), 2),
    xx.iloc[::2],
    rotation=90
)
plt.title("x")

plt.grid(True)

plt.tight_layout()
plt.savefig("x_data.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# x軸：四半期を文字列として扱う
x = input_csv.iloc[:, 0].astype(str)

# y軸：Y
Y = input_csv["Y"]/1000

plt.figure(figsize=(8, 4))

plt.plot(
x,
Y,
linestyle="solid",
marker="o"
)

plt.ylabel("1 billion yen")
plt.xticks(
    range(0, len(x), 2),
    x.iloc[::2],
    rotation=90
)
plt.title("Y")

plt.grid(True)

plt.tight_layout()
plt.savefig("Y_data.png", dpi=300, bbox_inches="tight")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Kohsu\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'Y'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[81], line 5
#       1 # x軸：四半期を文字列として扱う
#       2 x = input_csv.iloc[:, 0].astype(str)
#       3
#       4 # y軸：Y
# ----> 5 Y = input_csv["Y"]/1000
#       6
#
# File c:\Users\Kohsu\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File c:\Users\Kohsu\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'Y'

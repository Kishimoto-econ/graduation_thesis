# %%
import pandas as pd
import matplotlib.pyplot as plt

input_csv = pd.read_csv(
r"C:\Users\Kohsu\Desktop\graduation_thesis\progress\data\data.csv"
)

# x軸：四半期を文字列として扱う
x = input_csv.iloc[:, 0].astype(str)

# y軸：R
R = input_csv["R"]

plt.figure(figsize=(8, 4))

plt.plot(
x,
R,
linestyle="solid",
marker="o"
)

plt.ylabel("%")
plt.xticks(
    range(0, len(x), 2),
    x.iloc[::2],
    rotation=90
)
plt.title("R")

plt.grid(True)

plt.tight_layout()
plt.savefig("R_data.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# x軸：四半期を文字列として扱う
x = input_csv.iloc[:, 0].astype(str)

# y軸：b
b = input_csv["b"]/1000

plt.figure(figsize=(8, 4))

plt.plot(
x,
b,
linestyle="solid",
marker="o"
)

plt.ylabel("1 billion yen")
plt.xticks(
    range(0, len(x), 2),
    x.iloc[::2],
    rotation=90
)
plt.title("b")

plt.grid(True)

plt.tight_layout()
plt.savefig("b_data.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# x軸：四半期を文字列として扱う
x = input_csv.iloc[:, 0].astype(str)

# y軸：k
k = input_csv["k"]/1000

plt.figure(figsize=(8, 4))

plt.plot(
x,
k,
linestyle="solid",
marker="o"
)

plt.ylabel("1 billion yen")
plt.xticks(
    range(0, len(x), 2),
    x.iloc[::2],
    rotation=90
)
plt.title("k")

plt.grid(True)

plt.tight_layout()
plt.savefig("k_data.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# x軸：四半期を文字列として扱う
xx = input_csv.iloc[:, 0].astype(str)

# y軸：x
x = input_csv["x"]/1000

plt.figure(figsize=(8, 4))

plt.plot(
xx,
x,
linestyle="solid",
marker="o"
)

plt.ylabel("1 billion yen")
plt.xticks(
    range(0, len(xx), 2),
    xx.iloc[::2],
    rotation=90
)
plt.title("x")

plt.grid(True)

plt.tight_layout()
plt.savefig("x_data.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# x軸：四半期を文字列として扱う
x = input_csv.iloc[:, 0].astype(str)

# y軸：N
N = input_csv["N"]/10

plt.figure(figsize=(8, 4))

plt.plot(
x,
N,
linestyle="solid",
marker="o"
)

plt.ylabel("1 billion yen")
plt.xticks(
    range(0, len(x), 2),
    x.iloc[::2],
    rotation=90
)
plt.title("N")

plt.grid(True)

plt.tight_layout()
plt.savefig("N_data.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# x軸：四半期を文字列として扱う
x = input_csv.iloc[:, 0].astype(str)

# y軸：Y
Y = input_csv["Y"]/1000

plt.figure(figsize=(8, 4))

plt.plot(
x,
Y,
linestyle="solid",
marker="o"
)

plt.ylabel("1 billion yen")
plt.xticks(
    range(0, len(x), 2),
    x.iloc[::2],
    rotation=90
)
plt.title("Y")

plt.grid(True)

plt.tight_layout()
plt.savefig("Y_data.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
# x軸：四半期を文字列として扱う
x = input_csv.iloc[:, 0].astype(str)

# y軸：労働分配率
labor = input_csv["labor_share"]

plt.figure(figsize=(8, 4))

plt.plot(
x,
labor,
linestyle="solid",
marker="o"
)

plt.ylabel("%")
plt.xticks(
    range(0, len(x), 2),
    x.iloc[::2],
    rotation=90
)
plt.title("Labor Share")

plt.grid(True)

plt.tight_layout()
plt.savefig("labor_share_data.png", dpi=300, bbox_inches="tight")
plt.show()
